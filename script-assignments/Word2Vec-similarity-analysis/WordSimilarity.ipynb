# %%
import random as rand
import gensim.downloader

# %% [markdown]
# Loading questions-words.txt corpus into a set of words

# %%
data = []
for line in open("questions-words.txt"):
    li=line.strip()
    if not li.startswith(":"):
        data.extend(line.rstrip().split())
data = list(set(data))

# %%
print(len(data))
for d in data:
    print(d)
# Out:
# 905
# Libreville
# Bahamas
# India
# yen
# Honduras
# Israeli
# Vaduz
# Bishkek
# knew
# Botswana
# French
# Fresno
# Athens
# Wichita
# Montevideo
# krone
# quietly
# convincing
# amazingly
# Manama
# Nicosia
# Oakland
# calmly
# possibly
# Gaborone
# generating
# struck
# stepdaughter
# dram
# finger
# swim
# hot
# inefficient
# Moldova
# lion
# colors
# melons
# mangoes
# amazing
# smaller
# jumped
# woman
# apparent
# weak
# Australian
# Budapest
# Albania
# rarely
# mango
# suddenly
# knowing
# Tehran
# Chisinau
# Tunis
# Louisiana
# strangest
# Colombia
# highest
# wrote
# sharp
# Baghdad
# ringgit
# Ohio
# Georgetown
# Austin
# Swedish
# lowest
# dinar
# greatest
# building
# Tirana
# Italy
# go
# feeding
# Slovakian
# Nicaragua
# Tegucigalpa
# quickest
# hryvnia
# great
# comfortable
# slower
# Azerbaijan
# reasonable
# short
# weirdest
# paying
# unpleasant
# new
# Texas
# mouse
# Vientiane
# Arlington
# Greek
# seriously
# weaker
# Slovakia
# Seattle
# he
# happy
# inventing
# Cambodian
# Kathmandu
# Irving
# informed
# Rwanda
# Iceland
# fed
# Belize
# Eritrea
# king
# unfortunately
# spent
# Venezuela
# Tbilisi
# Slovenia
# Poland
# brighter
# melon
# listens
# works
# England
# ethical
# quicker
# implemented
# Henderson
# Irish
# dad
# Nevada
# sons
# Warsaw
# computers
# Roseau
# Greece
# Bujumbura
# father
# Ghana
# precise
# Nigeria
# screamed
# implementing
# kwanza
# banana
# Tallinn
# large
# darkest
# Hanoi
# longer
# mom
# decreasing
# fast
# bottles
# shortest
# took
# Orlando
# color
# eye
# long
# weird
# Riga
# sits
# Finland
# Conakry
# provide
# occasional
# vanish
# leu
# listening
# riel
# wife
# tallest
# shuffles
# Bamako
# Chinese
# swam
# Oman
# cheerful
# Indiana
# aware
# Qatar
# cheap
# English
# fingers
# infrequent
# obviously
# Lisbon
# dream
# Zimbabwe
# Mexican
# fell
# brothers
# road
# simple
# Kansas
# Chandler
# Turkey
# decreases
# decreased
# Lebanon
# Bangladesh
# peso
# undecided
# say
# Danish
# Austrian
# snake
# rational
# Laos
# hid
# Nebraska
# cows
# luckiest
# falling
# vanishes
# Maputo
# Spokane
# deep
# Senegal
# Japan
# impossible
# finds
# Ukraine
# Cambodia
# prince
# Fremont
# Khartoum
# goats
# Louisville
# rare
# boy
# dog
# Michigan
# flew
# cloud
# lucky
# Tampa
# vanishing
# Nepal
# low
# Sofia
# naira
# computer
# screams
# increased
# Japanese
# bigger
# generate
# Albanian
# Dutch
# Minsk
# completely
# precisely
# impossibly
# smallest
# shuffle
# hottest
# Detroit
# slow
# Mali
# Arizona
# serious
# play
# krona
# Ottawa
# Austria
# lats
# logical
# consistent
# usually
# faster
# predicting
# going
# Kazakhstan
# unclear
# weakest
# goes
# buildings
# his
# pineapples
# invent
# unsure
# Kyrgyzstan
# possible
# Kampala
# likely
# Bulgaria
# strongest
# fortunate
# machine
# Pennsylvania
# Belarus
# Asmara
# enhanced
# cheerfully
# Gambia
# Mozambique
# Uruguay
# writes
# grandmother
# Philadelphia
# Spain
# Yerevan
# Georgia
# Phoenix
# calm
# quick
# Netherlands
# speaks
# informative
# Paris
# safely
# Amman
# girl
# free
# simpler
# plays
# Vilnius
# London
# loud
# Minnesota
# won
# Macedonia
# sold
# Macedonian

# %% [markdown]
# Loading pre-trained word2vec model

# %%
wv = gensim.downloader.load('word2vec-google-news-300')

# %% [markdown]
# Cosine similarity function

# %%
def similarity(word1, word2):
    return wv.similarity(word1, word2)

# %% [markdown]
# Similarity analysis on randomly selected pairs of words from the corpus

# %%
pairs = []
for i in range(10):
    pairs.append((data[rand.randrange(len(data))], data[rand.randrange(len(data))]))
for pair in pairs:
    try:
        print('%r\t%r\t%.2f' % (pair[0], pair[1], similarity(pair[0], pair[1])))
    except KeyError as err:
        print(err)
# Out:
# 'Armenia'	'Japan'	0.25
# 'Malta'	'Mozambique'	0.35
# 'Antananarivo'	'Russian'	0.16
# 'Portuguese'	'Cyprus'	0.32
# 'unethical'	'machine'	0.03
# 'Cincinnati'	'Miami'	0.55
# 'eagle'	'Hialeah'	-0.00
# 'Canberra'	'swiftly'	0.08
# 'tighter'	'slowly'	0.20
# 'likely'	'jumping'	0.05

# %% [markdown]
# Function for getting n most similar words of a word

# %%
def most_similar(word, n):
    return wv.most_similar(positive=word, topn=n)

# %% [markdown]
# Getting 3 most similar words of random words along with cosine similarity

# %%
for i in range(10):
    word = data[rand.randrange(len(data))]
    try:
        print(word, ':', most_similar(word, 3))
    except KeyError as err:
        print(err)
# Out:
# Thailand : [('Thai', 0.7535778880119324), ('Cambodia', 0.713142991065979), ('Bangkok', 0.7014990448951721)]
# pig : [('pigs', 0.802344799041748), ('swine', 0.703639030456543), ('piglet', 0.7028454542160034)]
# thinking : [('Thinking', 0.6526100039482117), ('think', 0.6110400557518005), ('dreaming', 0.6062067747116089)]
# Baltimore : [('Maryland', 0.6851369142532349), ('Philadelphia', 0.6769400835037231), ('Balitmore', 0.6574479341506958)]
# Florida : [('Tampa', 0.7329097986221313), ('Tallahassee', 0.6981877088546753), ('Fort_Lauderdale', 0.6761346459388733)]
# possible : [('humanly_possible', 0.5423455238342285), ('practicable', 0.505595862865448), ('potential', 0.5038020610809326)]
# Tallahassee : [('Gainesville', 0.742448091506958), ('DeLand', 0.6997937560081482), ('Sarasota', 0.6987807750701904)]
# loud : [('noisy', 0.6621274352073669), ('loudly', 0.6364006996154785), ('fer_cryin', 0.6316129565238953)]
# younger : [('older', 0.8020765781402588), ('Elena_Losina_co', 0.640603244304657), ('young', 0.635094165802002)]
# Israel : [('Israeli', 0.8130459785461426), ('Israelis', 0.779090940952301), ('Palestinians', 0.7580956220626831)]
